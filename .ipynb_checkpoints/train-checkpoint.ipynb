# %%
#Mendownload dataset
# !gdown 1PwzKTSqLUEKMqTPnII6D3GkHHd1Xtfba

#Melakukan unzip file dataset
# !unzip -q lung_image_sets.zip

#Menghapus file zip
# !rm -rf lung_image_sets.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1PwzKTSqLUEKMqTPnII6D3GkHHd1Xtfba
# From (redirected): https://drive.google.com/uc?id=1PwzKTSqLUEKMqTPnII6D3GkHHd1Xtfba&confirm=t&uuid=e5904ec7-6e0d-4c97-9a4c-8142f5996469
# To: /workspace/TelU-TugasAkhir/lung_image_sets.zip
# 100%|████████████████████████████████████████| 929M/929M [00:43<00:00, 21.3MB/s]

# %%
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
import shutil   
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input,Conv2D, MaxPooling2D, Flatten,BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.efficientnet import preprocess_input as efficientnet_preprocess
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from scipy.stats import mode
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetB4, EfficientNetB5, EfficientNetB6, EfficientNetB7,MobileNetV2,DenseNet201
import time

# %%
CWD = os.getcwd()
CWD
# Out:
# '/workspace/TelU-TugasAkhir'

# %%
base_dir = os.path.join(CWD, 'lung_image_sets')

def split_data(base_dir, train_ratio=0.72, val_ratio=0.2, test_ratio=0.08):
    
    sets = ['lung_aca', 'lung_n', 'lung_scc']
    
    destination = './splitted_lung' 

    for set_name in sets:
        set_path = os.path.join(base_dir, set_name)
        images = os.listdir(set_path)

        # Split into train, val, and test
        train_images, temp_images = train_test_split(images, train_size=train_ratio, random_state=24)
        val_images, test_images = train_test_split(temp_images, test_size=test_ratio/(test_ratio + val_ratio),random_state=24)
        
        # Create directories if they don't exist
        for split in ['train', 'val', 'test']:
            split_dir = os.path.join(destination, split, set_name)
            os.makedirs(split_dir, exist_ok=True)
        
        # Move the images to their respective directories
        for image in train_images:
            shutil.copy(os.path.join(set_path, image), os.path.join(destination, 'train', set_name, image))
        
        for image in val_images:
            shutil.copy(os.path.join(set_path, image), os.path.join(destination, 'val', set_name, image))
        
        for image in test_images:
            shutil.copy(os.path.join(set_path, image), os.path.join(destination, 'test', set_name, image))

    print("Data splitted into train, validation, and test sets.")

# %%
split_data(base_dir)
# Out:
# Data splitted into train, validation, and test sets.

# %%
def create_image_generators(train_dir, val_dir, test_dir, target_size=(224, 224), batch_size=32, preprocessing_func=None):
    # ImageDataGenerator without augmentation (for comparison)
    train_datagen_no_aug = ImageDataGenerator()

    # ImageDataGenerator with augmentation
    train_datagen_with_aug = ImageDataGenerator(
        rotation_range=20,
        # width_shift_range=0.2,
        # height_shift_range=0.2,
        shear_range=0.2,  # Shear angle in counter-clockwise direction in degrees
        zoom_range=0.2,   # Randomly zoom inside pictures
        horizontal_flip=True,
        vertical_flip=True,  # Flip the images vertically as well
        fill_mode='nearest',  # Strategy to fill newly created pixels
        brightness_range=[0.8, 1.2],  # Adjust brightness between 80% and 120%
    )
    
    # For validation and test sets, we do not apply augmentation
    val_test_datagen = ImageDataGenerator(
        preprocessing_function=preprocessing_func
    )
    
    # Flow images from directories
    train_generator_no_aug = train_datagen_no_aug.flow_from_directory(
        train_dir,
        target_size=target_size,
        batch_size=batch_size,
        shuffle=True,
        class_mode='categorical'
    )
    
    train_generator_with_aug = train_datagen_with_aug.flow_from_directory(
        train_dir,
        target_size=target_size,
        batch_size=batch_size,
        shuffle=True,
        class_mode='categorical'
    )
    
    val_generator = val_test_datagen.flow_from_directory(
        val_dir,
        target_size=target_size,
        batch_size=batch_size,
        shuffle=True,
        class_mode='categorical'
    )
    
    test_generator = val_test_datagen.flow_from_directory(
        test_dir,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False
    )
    
    return train_generator_no_aug, train_generator_with_aug, val_generator, test_generator

# %%
# Pilih fungsi preprocessing yang sesuai dengan model
preprocess_input_func = efficientnet_preprocess

train_dir = os.path.join(CWD,'splitted/train')
val_dir = os.path.join(CWD,'splitted/val')
test_dir = os.path.join(CWD,'splitted/test')

train_lung_dir = os.path.join(CWD,'splitted_lung/train')
val_lung_dir = os.path.join(CWD,'splitted_lung/val')
test_lung_dir = os.path.join(CWD,'splitted_lung/test')

# %%
def create_model(base_model_class, input_shape):
    base_model = base_model_class(input_shape=input_shape, include_top=False, weights='imagenet')
    base_model.trainable = True  # Freeze the base model

    total_layers = len(base_model.layers)
    for layer in base_model.layers[(int(0.5 * total_layers)):]:
        layer.trainable =  False

    inputs = Input(shape=input_shape)
    # Tidak perlu preprocessing lagi di sini
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)

    outputs = Dense(5, activation='softmax')(x)

    model = Model(base_model.inputs, outputs)

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def create_base_cnn(input_shape, num_classes=5):
    # Define the input
    inputs = Input(shape=input_shape)
    
    # First Convolutional Block
    x = Conv2D(32, (3, 3), activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    
    # Second Convolutional Block
    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)  # Moderate dropout to prevent overfitting
    
    # Third Convolutional Block
    x = Conv2D(128, (3, 3), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)  # Moderate dropout
    
    # Flatten and Fully Connected Layers
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    
    # Output Layer
    outputs = Dense(num_classes, activation='softmax')(x)
    
    # Define the model
    model = Model(inputs=inputs, outputs=outputs)
    
    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
def create_callbacks(model_name, checkpoint_path, patience=3, reduce_lr_factor=0.5, reduce_lr_patience=2):
    if not os.path.exists(checkpoint_path):
        os.makedirs(checkpoint_path)

    saving_path = os.path.join(checkpoint_path, f'model_{model_name}.h5')

    # ModelCheckpoint to save the best model based on validation accuracy
    checkpoint = ModelCheckpoint(
        filepath=saving_path,  # Path to save the model
        monitor='val_accuracy',    # Monitor validation accuracy
        save_best_only=True,       # Save the model only when val_accuracy improves
        mode='max',                # Maximize validation accuracy
        verbose=1                  # Show messages when saving
    )
    
    # EarlyStopping to stop training when the model stops improving
    early_stopping = EarlyStopping(
        monitor='val_loss',        # Monitor validation loss
        patience=patience,         # Stop after 'patience' epochs without improvement
        mode='min',                # Minimize validation loss
        restore_best_weights=True, # Restore the best weights after stopping
        verbose=1
    )
    
    # ReduceLROnPlateau to reduce the learning rate when a plateau is detected
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',        # Monitor validation loss
        factor=reduce_lr_factor,   # Factor by which to reduce learning rate
        patience=reduce_lr_patience, # How many epochs to wait before reducing
        mode='min',                # Minimize validation loss
        min_lr=1e-6,               # Lower bound on the learning rate
        verbose=1
    )
    
    # Return the list of callbacks
    return [checkpoint, early_stopping, reduce_lr]

# Define the path to save the best model
checkpoint_path = CWD + '/model/weights'

# %%
# Fungsi untuk melatih model dan menampilkan grafik
def train_and_plot(model, model_name, train_generator, validation_generator, callbacks, epochs=10):
    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=epochs,
        callbacks= callbacks
    )

    # Create directories if they don't exist
    model_dir = os.path.join(CWD, 'model', 'saved_models')
    plot_dir = os.path.join(CWD, model_name)

    os.makedirs(model_dir, exist_ok=True)  # Ensure the model save directory exists
    os.makedirs(plot_dir, exist_ok=True)   # Ensure the plot directory exists

    # Plotting hasil
    plt.figure(figsize=(12, 4))

    # Plot training & validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'{model_name} Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'{model_name} Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Save the plot as an image in the respective folder
    plot_filename = os.path.join(plot_dir, f'{model_name}_training_plot.png')
    plt.savefig(plot_filename)  # Save the plot
    plt.show()

    # Save the model in the respective folder
    model_filename = os.path.join(model_dir, f'{model_name}.h5')
    model.save(model_filename)  # Save the trained model

    plt.show()
    return history, model

# %%
def show_cm_and_classification_report(model, test_generator, model_name):
    # Define directory for saving images and reports
    img_dir = os.path.join(CWD, f'{model_name}')
    os.makedirs(img_dir, exist_ok=True)  # Ensure the directory exists

    # Get predictions from the model
    Y_pred = model.predict(test_generator)
    y_pred = np.argmax(Y_pred, axis=1)

    # Get true labels
    y_true = test_generator.classes

    # Get class labels
    class_labels = list(test_generator.class_indices.keys())

    # Generate the classification report
    report = classification_report(y_true, y_pred, target_names=class_labels,digits=4)

    # Print classification report to console
    print("Classification Report:\n", report)

    # Save classification report to a text file
    report_filename = os.path.join(img_dir, f'{model_name}_classification_report.txt')
    with open(report_filename, 'w') as f:
        f.write(report)

    # Generate the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Plot the confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Save the confusion matrix as an image
    cm_filename = os.path.join(img_dir, f'{model_name}_confusion_matrix.png')
    plt.savefig(cm_filename)
    plt.show()

    return report_filename, cm_filename

# %%
def load_best_model(model_path):
    return tf.keras.models.load_model(model_path)

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(224, 224),  # Image size
    batch_size=128,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
callbacks_eb1 = create_callbacks(
    model_name='EfficientNetB1_224',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

efficientnet_b1 = create_model(EfficientNetB1, input_shape=(224, 224, 3))

history_b1, model_b1 = train_and_plot(efficientnet_b1, 'EfficientNetB1_224', train_generator_with_aug, val_generator, callbacks_eb1,epochs=25)
# Out:
# 2024-11-05 16:32:44.965899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22282 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 [==============================] - 2s 0us/step
# Epoch 1/25
# 2024-11-05 16:32:55.323510: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-11-05 16:32:56.206244: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-11-05 16:32:57.584150: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8905
# 2024-11-05 16:32:57.701480: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-11-05 16:32:58.388435: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xbf8c5f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-05 16:32:58.388451: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-11-05 16:32:58.394440: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-05 16:32:58.449228: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 141/141 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.8782
# Epoch 1: val_accuracy improved from -inf to 0.96460, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB1_224.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 141/141 [==============================] - 250s 2s/step - loss: 0.3273 - accuracy: 0.8782 - val_loss: 0.1266 - val_accuracy: 0.9646 - lr: 0.0010
# Epoch 2/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9826
# Epoch 2: val_accuracy did not improve from 0.96460
# 141/141 [==============================] - 207s 1s/step - loss: 0.0581 - accuracy: 0.9826 - val_loss: 0.1745 - val_accuracy: 0.9462 - lr: 0.0010
# Epoch 3/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9890
# Epoch 3: val_accuracy improved from 0.96460 to 0.98840, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB1_224.h5
# 141/141 [==============================] - 218s 2s/step - loss: 0.0383 - accuracy: 0.9890 - val_loss: 0.0335 - val_accuracy: 0.9884 - lr: 0.0010
# Epoch 4/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9928
# Epoch 4: val_accuracy did not improve from 0.98840
# 141/141 [==============================] - 205s 1s/step - loss: 0.0250 - accuracy: 0.9928 - val_loss: 0.0454 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 5/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9934
# Epoch 5: val_accuracy did not improve from 0.98840
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 141/141 [==============================] - 199s 1s/step - loss: 0.0196 - accuracy: 0.9934 - val_loss: 0.0393 - val_accuracy: 0.9854 - lr: 0.0010
# Epoch 6/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9969
# Epoch 6: val_accuracy improved from 0.98840 to 0.99420, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB1_224.h5
# 141/141 [==============================] - 199s 1s/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.0162 - val_accuracy: 0.9942 - lr: 5.0000e-04
# Epoch 7/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9978
# Epoch 7: val_accuracy improved from 0.99420 to 0.99860, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB1_224.h5
# 141/141 [==============================] - 179s 1s/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.0038 - val_accuracy: 0.9986 - lr: 5.0000e-04
# Epoch 8/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9978
# Epoch 8: val_accuracy did not improve from 0.99860
# 141/141 [==============================] - 190s 1s/step - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0093 - val_accuracy: 0.9966 - lr: 5.0000e-04
# Epoch 9/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9972
# Epoch 9: val_accuracy did not improve from 0.99860
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 141/141 [==============================] - 219s 2s/step - loss: 0.0110 - accuracy: 0.9972 - val_loss: 0.0314 - val_accuracy: 0.9896 - lr: 5.0000e-04
# Epoch 10/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989
# Epoch 10: val_accuracy improved from 0.99860 to 0.99920, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB1_224.h5
# 141/141 [==============================] - 232s 2s/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0034 - val_accuracy: 0.9992 - lr: 2.5000e-04
# Epoch 11/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9992
# Epoch 11: val_accuracy did not improve from 0.99920
# 141/141 [==============================] - 220s 2s/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0037 - val_accuracy: 0.9990 - lr: 2.5000e-04
# Epoch 12/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9989
# Epoch 12: val_accuracy improved from 0.99920 to 0.99940, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB1_224.h5
# 141/141 [==============================] - 210s 1s/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0027 - val_accuracy: 0.9994 - lr: 2.5000e-04
# Epoch 13/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 13: val_accuracy improved from 0.99940 to 0.99960, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB1_224.h5
# 141/141 [==============================] - 216s 2s/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0024 - val_accuracy: 0.9996 - lr: 2.5000e-04
# Epoch 14/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9996
# Epoch 14: val_accuracy did not improve from 0.99960
# 141/141 [==============================] - 216s 2s/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0110 - val_accuracy: 0.9972 - lr: 2.5000e-04
# Epoch 15/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9984
# Epoch 15: val_accuracy did not improve from 0.99960
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 141/141 [==============================] - 202s 1s/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.0028 - val_accuracy: 0.9994 - lr: 2.5000e-04
# Epoch 16/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9992
# Epoch 16: val_accuracy did not improve from 0.99960
# 141/141 [==============================] - 203s 1s/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0028 - val_accuracy: 0.9996 - lr: 1.2500e-04
# Epoch 17/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 17: val_accuracy did not improve from 0.99960
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 141/141 [==============================] - 196s 1s/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0070 - val_accuracy: 0.9978 - lr: 1.2500e-04
# Epoch 18/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 18: val_accuracy improved from 0.99960 to 0.99980, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB1_224.h5
# 141/141 [==============================] - 195s 1s/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9998 - lr: 6.2500e-05
# Epoch 19/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 19: val_accuracy did not improve from 0.99980
# 141/141 [==============================] - 209s 1s/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0032 - val_accuracy: 0.9994 - lr: 6.2500e-05
# Epoch 20/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 20: val_accuracy did not improve from 0.99980
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 141/141 [==============================] - 196s 1s/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0030 - val_accuracy: 0.9994 - lr: 6.2500e-05
# Epoch 21/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 21: val_accuracy did not improve from 0.99980
# 141/141 [==============================] - 194s 1s/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0051 - val_accuracy: 0.9986 - lr: 3.1250e-05
# Epoch 22/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 22: val_accuracy did not improve from 0.99980
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 141/141 [==============================] - 205s 1s/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0066 - val_accuracy: 0.9978 - lr: 3.1250e-05
# Epoch 23/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 23: val_accuracy did not improve from 0.99980
# Restoring model weights from the end of the best epoch: 18.
# 141/141 [==============================] - 224s 2s/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0061 - val_accuracy: 0.9978 - lr: 1.5625e-05
# Epoch 23: early stopping

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_b1, test_generator, 'EfficientNetB1_224')
# Out:
# 16/16 [==============================] - 14s 846ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     1.0000    1.0000    1.0000       400
#      colon_n     1.0000    1.0000    1.0000       400
#     lung_aca     1.0000    1.0000    1.0000       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     1.0000    1.0000    1.0000       400
#
#     accuracy                         1.0000      2000
#    macro avg     1.0000    1.0000    1.0000      2000
# weighted avg     1.0000    1.0000    1.0000      2000

# %%
def create_model_lung(base_model_class, input_shape):
    base_model = base_model_class(input_shape=input_shape, include_top=False, weights='imagenet')
    base_model.trainable = True  # Freeze the base model

    total_layers = len(base_model.layers)
    for layer in base_model.layers[(int(0.5 * total_layers)):]:
        layer.trainable =  False

    inputs = Input(shape=input_shape)
    # Tidak perlu preprocessing lagi di sini
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)

    outputs = Dense(3, activation='softmax')(x)

    model = Model(base_model.inputs, outputs)

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_lung_dir,
    val_dir=val_lung_dir,
    test_dir=test_lung_dir,
    target_size=(224, 224),  # Image size
    batch_size=128,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 10800 images belonging to 3 classes.
# Found 10800 images belonging to 3 classes.
# Found 3000 images belonging to 3 classes.
# Found 1200 images belonging to 3 classes.

# %%
callbacks_eb2_lung = create_callbacks(
    model_name='EfficientNetB2_lung',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

efficientnet_b2_lung = create_model_lung(EfficientNetB2, input_shape=(224, 224, 3))

history_b2_lung, model_b2_lung = train_and_plot(efficientnet_b2_lung, 'EfficientNetB2_lung', train_generator_with_aug, val_generator, callbacks_eb2_lung,epochs=25)
# Out:
# Epoch 1/25
# 2024-11-05 18:27:52.321814: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_3/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 85/85 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.8880
# Epoch 1: val_accuracy improved from -inf to 0.97600, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB2_lung.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 85/85 [==============================] - 144s 2s/step - loss: 0.2902 - accuracy: 0.8880 - val_loss: 0.0829 - val_accuracy: 0.9760 - lr: 0.0010
# Epoch 2/25
# 85/85 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9773
# Epoch 2: val_accuracy improved from 0.97600 to 0.97667, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB2_lung.h5
# 85/85 [==============================] - 97s 1s/step - loss: 0.0718 - accuracy: 0.9773 - val_loss: 0.0664 - val_accuracy: 0.9767 - lr: 0.0010
# Epoch 3/25
# 85/85 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9904
# Epoch 3: val_accuracy improved from 0.97667 to 0.99267, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNet
[==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 14: val_accuracy did not improve from 1.00000
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 85/85 [==============================] - 102s 1s/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0026 - val_accuracy: 0.9993 - lr: 2.5000e-04
# Epoch 15/25
# 85/85 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9993
# Epoch 15: val_accuracy did not improve from 1.00000
# Restoring model weights from the end of the best epoch: 10.
# 85/85 [==============================] - 97s 1s/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0038 - val_accuracy: 0.9990 - lr: 1.2500e-04
# Epoch 15: early stopping

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_b2_lung, test_generator, 'EfficientNetB2_lung')
# Out:
# 10/10 [==============================] - 9s 832ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#     lung_aca     1.0000    1.0000    1.0000       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     1.0000    1.0000    1.0000       400
#
#     accuracy                         1.0000      1200
#    macro avg     1.0000    1.0000    1.0000      1200
# weighted avg     1.0000    1.0000    1.0000      1200

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(224, 224),  # Image size
    batch_size=128,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
callbacks_eb2 = create_callbacks(
    model_name='EfficientNetB2_224',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

efficientnet_b2 = create_model(EfficientNetB2, input_shape=(224, 224, 3))

history_b2, model_b2 = train_and_plot(efficientnet_b2, 'EfficientNetB2_224', train_generator_with_aug, val_generator, callbacks_eb2,epochs=25)
# Out:
# Epoch 1/25
# 2024-11-05 18:58:45.675769: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_5/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 141/141 [==============================] - ETA: 0s - loss: 0.3140 - accuracy: 0.8812
# Epoch 1: val_accuracy improved from -inf to 0.97400, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB2_224.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 141/141 [==============================] - 232s 2s/step - loss: 0.3140 - accuracy: 0.8812 - val_loss: 0.0914 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 2/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9809
# Epoch 2: val_accuracy did not improve from 0.97400
# 141/141 [==============================] - 208s 1s/step - loss: 0.0641 - accuracy: 0.9809 - val_loss: 0.2433 - val_accuracy: 0.9342 - lr: 0.0010
# Epoch 3/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9904
# Epoch 3: val_accuracy did not improve from 0.97400
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 141/141 [==============================] - 207s 1s/step - loss: 0.0388 - accuracy: 0.9904 - val_loss: 0.2627 - val_accuracy: 0.9286 - lr: 0.0010
# Epoch 4/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9963
# Epoch 4: val_accuracy improved from 0.97400 to 0.98060, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB2_224.h5
# 141/141 [==============================] - 202s 1s/step - loss: 0.0147 - accuracy: 0.9963 - val_loss: 0.0640 - val_accuracy: 0.9806 - lr: 5.0000e-04
# Epoch 5/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.9962
# Epoch 5: val_accuracy improved from 0.98060 to 0.99960, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB2_224.h5
# 141/141 [==============================] - 203s 1s/step - loss: 0.0140 - accuracy: 0.9962 - val_loss: 0.0021 - val_accuracy: 0.9996 - lr: 5.0000e-04
# Epoch 6/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9970
# Epoch 6: val_accuracy did not improve from 0.99960
# 141/141 [==============================] - 201s 1s/step - loss: 0.0126 - accuracy: 0.9970 - val_loss: 0.0048 - val_accuracy: 0.9980 - lr: 5.0000e-04
# Epoch 7/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9985
# Epoch 7: val_accuracy did not improve from 0.99960
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 141/141 [==============================] - 201s 1s/step - loss: 0.0066 - accuracy: 0.9985 - val_loss: 0.0299 - val_accuracy: 0.9910 - lr: 5.0000e-04
# Epoch 8/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9986
# Epoch 8: val_accuracy did not improve from 0.99960
# 141/141 [==============================] - 202s 1s/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0070 - val_accuracy: 0.9974 - lr: 2.5000e-04
# Epoch 9/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9988
# Epoch 9: val_accuracy improved from 0.99960 to 0.99980, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB2_224.h5
# 141/141 [==============================] - 206s 1s/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 3.9635e-04 - val_accuracy: 0.9998 - lr: 2.5000e-04
# Epoch 10/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9988
# Epoch 10: val_accuracy did not improve from 0.99980
# 141/141 [==============================] - 208s 1s/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0017 - val_accuracy: 0.9998 - lr: 2.5000e-04
# Epoch 11/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9984
# Epoch 11: val_accuracy did not improve from 0.99980
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 141/141 [==============================] - 210s 1s/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.0024 - val_accuracy: 0.9992 - lr: 2.5000e-04
# Epoch 12/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9987
# Epoch 12: val_accuracy did not improve from 0.99980
# 141/141 [==============================] - 206s 1s/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 9.9075e-04 - val_accuracy: 0.9996 - lr: 1.2500e-04
# Epoch 13/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9991
# Epoch 13: val_accuracy did not improve from 0.99980
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 141/141 [==============================] - 208s 1s/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 6.4579e-04 - val_accuracy: 0.9998 - lr: 1.2500e-04
# Epoch 14/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 14: val_accuracy did not improve from 0.99980
# Restoring model weights from the end of the best epoch: 9.
# 141/141 [==============================] - 212s 2s/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0011 - val_accuracy: 0.9996 - lr: 6.2500e-05
# Epoch 14: early stopping

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_b2, test_generator, 'EfficientNetB2_224')
# Out:
# 16/16 [==============================] - 13s 808ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     1.0000    1.0000    1.0000       400
#      colon_n     1.0000    1.0000    1.0000       400
#     lung_aca     1.0000    1.0000    1.0000       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     1.0000    1.0000    1.0000       400
#
#     accuracy                         1.0000      2000
#    macro avg     1.0000    1.0000    1.0000      2000
# weighted avg     1.0000    1.0000    1.0000      2000

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(380, 380),  # Image size
    batch_size=32,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
callbacks_eb4 = create_callbacks(
    model_name='EfficientNetB4',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

efficientnet_b4 = create_model(EfficientNetB4, input_shape=(380, 380, 3))

history_b4, model_b4 = train_and_plot(efficientnet_b4, 'EfficientNetB4', train_generator_with_aug, val_generator, callbacks_eb4,epochs=25)
# Out:
# Epoch 1/25
# 2024-11-05 20:01:12.019406: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_7/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 563/563 [==============================] - ETA: 0s - loss: 0.1920 - accuracy: 0.9338
# Epoch 1: val_accuracy improved from -inf to 0.99360, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB4.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 563/563 [==============================] - 389s 665ms/step - loss: 0.1920 - accuracy: 0.9338 - val_loss: 0.0185 - val_accuracy: 0.9936 - lr: 0.0010
# Epoch 2/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9809
# Epoch 2: val_accuracy did not improve from 0.99360
# 563/563 [==============================] - 367s 652ms/step - loss: 0.0660 - accuracy: 0.9809 - val_loss: 0.0314 - val_accuracy: 0.9890 - lr: 0.0010
# Epoch 3/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9868
# Epoch 3: val_accuracy did not improve from 0.99360
# 563/563 [==============================] - 360s 638ms/step - loss: 0.0445 - accuracy: 0.9868 - val_loss: 0.0183 - val_accuracy: 0.9922 - lr: 0.0010
# Epoch 4/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9906
# Epoch 4: val_accuracy improved from 0.99360 to 0.99600, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB4.h5
# 563/563 [==============================] - 363s 645ms/step - loss: 0.0358 - accuracy: 0.9906 - val_loss: 0.0114 - val_accuracy: 0.9960 - lr: 0.0010
# Epoch 5/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9924
# Epoch 5: val_accuracy did not improve from 0.99600
# 563/563 [==============================] - 362s 643ms/step - loss: 0.0256 - accuracy: 0.9924 - val_loss: 0.0132 - val_accuracy: 0.9960 - lr: 0.0010
# Epoch 6/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9909
# Epoch 6: val_accuracy did not improve from 0.99600
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 563/563 [==============================] - 364s 646ms/step - loss: 0.0319 - accuracy: 0.9909 - val_loss: 0.0332 - val_accuracy: 0.9944 - lr: 0.0010
# Epoch 7/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9953
# Epoch 7: val_accuracy improved from 0.99600 to 0.99940, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB4.h5
# 563/563 [==============================] - 361s 640ms/step - loss: 0.0167 - accuracy: 0.9953 - val_loss: 0.0023 - val_accuracy: 0.9994 - lr: 5.0000e-04
# Epoch 8/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9981
# Epoch 8: val_accuracy improved from 0.99940 to 1.00000, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB4.h5
# 563/563 [==============================] - 358s 636ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.0010 - val_accuracy: 1.0000 - lr: 5.0000e-04
# Epoch 9/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9982
# Epoch 9: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 368s 652ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0022 - val_accuracy: 0.9994 - lr: 5.0000e-04
# Epoch 10/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9959
# Epoch 10: val_accuracy did not improve from 1.00000
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 563/563 [==============================] - 370s 657ms/step - loss: 0.0187 - accuracy: 0.9959 - val_loss: 0.0030 - val_accuracy: 0.9994 - lr: 5.0000e-04
# Epoch 11/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9976
# Epoch 11: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 366s 650ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0031 - val_accuracy: 0.9992 - lr: 2.5000e-04
# Epoch 12/25
# 497/563 [=========================>....] - ETA: 38s - loss: 0.0044 - accuracy: 0.9987
# Epoch 12: val_accuracy did not improve from 1.00000
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 563/563 [==============================] - 369s 654ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0010 - val_accuracy: 0.9998 - lr: 2.5000e-04
# Epoch 13/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 13: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 367s 651ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 4.3951e-04 - val_accuracy: 0.9998 - lr: 1.2500e-04
# Epoch 14/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9985
# Epoch 14: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 369s 655ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.0019 - val_accuracy: 0.9992 - lr: 1.2500e-04
# Epoch 15/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 15: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 367s 650ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 6.3079e-05 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 16/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9991
# Epoch 16: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 369s 655ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 2.4637e-05 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 17/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9994
# Epoch 17: val_accuracy did not improve from 1.00000
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 563/563 [==============================] - 370s 656ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 1.0917e-04 - val_accuracy: 1.0000 - lr: 1.2500e-04
# Epoch 18/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 18: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 375s 665ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 2.0030e-05 - val_accuracy: 1.0000 - lr: 6.2500e-05
# Epoch 19/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996
# Epoch 19: val_accuracy did not improve from 1.00000
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 563/563 [==============================] - 406s 721ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 4.2707e-04 - val_accuracy: 0.9998 - lr: 6.2500e-05
# Epoch 20/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9993
# Epoch 20: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 385s 684ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 3.8337e-05 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 21/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9995
# Epoch 21: val_accuracy did not improve from 1.00000
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 563/563 [==============================] - 367s 651ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 1.7901e-04 - val_accuracy: 1.0000 - lr: 3.1250e-05
# Epoch 22/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 22: val_accuracy did not improve from 1.00000
# 563/563 [==============================] - 363s 645ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 1.0916e-04 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 23/25
# 563/563 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 23: val_accuracy did not improve from 1.00000
# Restoring model weights from the end of the best epoch: 18.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 563/563 [==============================] - 369s 655ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 1.6890e-04 - val_accuracy: 1.0000 - lr: 1.5625e-05
# Epoch 23: early stopping

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_b4, test_generator, 'EfficientNetB4')
# Out:
# 63/63 [==============================] - 17s 251ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     1.0000    1.0000    1.0000       400
#      colon_n     1.0000    1.0000    1.0000       400
#     lung_aca     1.0000    1.0000    1.0000       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     1.0000    1.0000    1.0000       400
#
#     accuracy                         1.0000      2000
#    macro avg     1.0000    1.0000    1.0000      2000
# weighted avg     1.0000    1.0000    1.0000      2000

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(456, 456),  # Image size
    batch_size=16,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
callbacks_eb5 = create_callbacks(
    model_name='EfficientNetB5',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

efficientnet_b5 = create_model(EfficientNetB5, input_shape=(456, 456, 3))

history_b5, model_b5 = train_and_plot(efficientnet_b5, 'EfficientNetB5', train_generator_with_aug, val_generator, callbacks_eb5,epochs=25)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 5s 0us/step
# Epoch 1/25
# 2024-11-05 22:23:22.860601: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_8/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
#  857/1125 [=====================>........] - ETA: 1:42 - loss: 0.2488 - accuracy: 0.9122
# Epoch 1: val_accuracy improved from -inf to 0.98940, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB5.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1125/1125 [==============================] - 497s 426ms/step - loss: 0.2146 - accuracy: 0.9253 - val_loss: 0.0472 - val_accuracy: 0.9894 - lr: 0.0010
# Epoch 2/25
# 1125/1125 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9730
# Epoch 2: val_accuracy did not improve from 0.98940
# 1125/1125 [==============================] - 472s 419ms/step - loss: 0.0830 - accuracy: 0.9730 - val_loss: 0.0513 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 3/25
# 1125/1125 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9818
# Epoch 3: val_accuracy improved from 0.98940 to 0.99060, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB5.h5
# 1125/1125 [==============================] - 467s 415ms/step - loss: 0.0576 - accuracy: 0.9818 - val_loss: 0.0236 - val_accuracy: 0.9906 - lr: 0.0010
# Epoch 4/25
#  740/1125 [==================>...........] - ETA: 2:26 - loss: 0.0595 - accuracy: 0.9823
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
[==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9993
# Epoch 18: val_accuracy did not improve from 0.99980
# Restoring model weights from the end of the best epoch: 13.
# 1125/1125 [==============================] - 465s 413ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 4.4643e-04 - val_accuracy: 0.9998 - lr: 3.1250e-05
# Epoch 18: early stopping

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_b5, test_generator, 'EfficientNetB5')
# Out:
# 125/125 [==============================] - 18s 137ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     1.0000    1.0000    1.0000       400
#      colon_n     1.0000    1.0000    1.0000       400
#     lung_aca     1.0000    1.0000    1.0000       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     1.0000    1.0000    1.0000       400
#
#     accuracy                         1.0000      2000
#    macro avg     1.0000    1.0000    1.0000      2000
# weighted avg     1.0000    1.0000    1.0000      2000

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(512, 512),  # Image size
    batch_size=8,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
callbacks_eb6 = create_callbacks(
    model_name='EfficientNetB6',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

efficientnet_b6 = create_model(EfficientNetB6, input_shape=(512, 512, 3))

history_b6, model_b6 = train_and_plot(efficientnet_b6, 'EfficientNetB6', train_generator_with_aug, val_generator, callbacks_eb6,epochs=25)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165234480/165234480 [==============================] - 7s 0us/step
# Epoch 1/25
# 2024-11-06 00:45:11.026834: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_9/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2250/2250 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9253
# Epoch 1: val_accuracy improved from -inf to 0.98320, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB6.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2250/2250 [==============================] - 709s 306ms/step - loss: 0.2289 - accuracy: 0.9253 - val_loss: 0.0457 - val_accuracy: 0.9832 - lr: 0.0010
# Epoch 2/25
# 2250/2250 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9611
# Epoch 2: val_accuracy did not improve from 0.98320
# 2250/2250 [==============================] - 685s 305ms/step - loss: 0.1252 - accuracy: 0.9611 - val_loss: 0.0623 - val_accuracy: 0.9758 - lr: 0.0010
# Epoch 3/25
# 2250/2250 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9712
# Epoch 3: val_accuracy did not improve from 0.98320
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2250/2250 [==============================] - 686s 305ms/step - loss: 0.0931 - accuracy: 0.9712 - val_loss: 0.0533 - val_accuracy: 0.9774 - lr: 0.0010
# Epoch 4/25
# 2250/2250 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9840
# Epoch 4: val_accuracy improved from 0.98320 to 0.98340, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNet
ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 4.3769e-04 - val_accuracy: 0.9996 - lr: 6.2500e-05
# Epoch 25/25
# 2250/2250 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9994
# Epoch 25: val_accuracy did not improve from 1.00000
# Restoring model weights from the end of the best epoch: 20.
# 2250/2250 [==============================] - 687s 305ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 8.4674e-04 - val_accuracy: 0.9996 - lr: 3.1250e-05
# Epoch 25: early stopping

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_b6, test_generator, 'EfficientNetB6')
# Out:
# 250/250 [==============================] - 17s 65ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     1.0000    1.0000    1.0000       400
#      colon_n     1.0000    1.0000    1.0000       400
#     lung_aca     1.0000    1.0000    1.0000       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     1.0000    1.0000    1.0000       400
#
#     accuracy                         1.0000      2000
#    macro avg     1.0000    1.0000    1.0000      2000
# weighted avg     1.0000    1.0000    1.0000      2000

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(224, 224),  # Image size
    batch_size=64,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
# Record the start time
start_time = time.time()

# %%
callbacks_eb3 = create_callbacks(
    model_name='EfficientNetB3_224',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

efficientnet_b3 = create_model(EfficientNetB3, input_shape=(224, 224, 3))

history_b3_224, model_b3_224 = train_and_plot(efficientnet_b3, 'EfficientNetB3_224', train_generator_with_aug, val_generator, callbacks_eb3,epochs=25)
# Out:
# Epoch 1/25
# 2024-11-06 15:45:25.097591: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 282/282 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9194
# Epoch 1: val_accuracy improved from -inf to 0.95340, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB3_224.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 282/282 [==============================] - 249s 842ms/step - loss: 0.2252 - accuracy: 0.9194 - val_loss: 0.1924 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 2/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9817
# Epoch 2: val_accuracy improved from 0.95340 to 0.97220, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB3_224.h5
# 282/282 [==============================] - 226s 801ms/step - loss: 0.0675 - accuracy: 0.9817 - val_loss: 0.1048 - val_accuracy: 0.9722 - lr: 0.0010
# Epoch 3/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9877
# Epoch 3: val_accuracy improved from 0.97220 to 0.99060, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB3_224.h5
# 282/282 [==============================] - 225s 797ms/step - loss: 0.0404 - accuracy: 0.9877 - val_loss: 0.0344 - val_accuracy: 0.9906 - lr: 0.0010
# Epoch 4/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9863
# Epoch 4: val_accuracy improved from 0.99060 to 0.99520, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB3_224.h5
# 282/282 [==============================] - 227s 807ms/step - loss: 0.0457 - accuracy: 0.9863 - val_loss: 0.0176 - val_accuracy: 0.9952 - lr: 0.0010
# Epoch 5/25
# 282/282 [==============================] - ETA: 0s - loss: 0.
ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9996 - lr: 1.2500e-04
# Epoch 18/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 18: val_accuracy did not improve from 0.99980
# Restoring model weights from the end of the best epoch: 13.
# 282/282 [==============================] - 225s 798ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.0016 - val_accuracy: 0.9994 - lr: 6.2500e-05
# Epoch 18: early stopping

# %%
# Record the end time
end_time = time.time()

# Calculate and print the training time
training_time = end_time - start_time
print(f"Training time: {training_time / 60:.2f} minutes")
# Out:
# Training time: 65.63 minutes

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_b3_224, test_generator, 'EfficientNetB3_224')
# Out:
# 32/32 [==============================] - 15s 446ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     0.9975    1.0000    0.9988       400
#      colon_n     1.0000    0.9975    0.9987       400
#     lung_aca     1.0000    1.0000    1.0000       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     1.0000    1.0000    1.0000       400
#
#     accuracy                         0.9995      2000
#    macro avg     0.9995    0.9995    0.9995      2000
# weighted avg     0.9995    0.9995    0.9995      2000

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(224, 224),  # Image size
    batch_size=64,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
# Record the start time
start_time = time.time()

# %%
callbacks_eb4 = create_callbacks(
    model_name='EfficientNetB4_224',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

efficientnet_b4 = create_model(EfficientNetB4, input_shape=(224, 224, 3))

history_b4_224, model_b4_224 = train_and_plot(efficientnet_b4, 'EfficientNetB4_224', train_generator_with_aug, val_generator, callbacks_eb4,epochs=25)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 [==============================] - 3s 0us/step
# Epoch 1/25
# 2024-11-06 16:59:56.036537: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_3/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 282/282 [==============================] - ETA: 0s - loss: 0.2639 - accuracy: 0.9023
# Epoch 1: val_accuracy improved from -inf to 0.97420, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB4_224.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 282/282 [==============================] - 247s 823ms/step - loss: 0.2639 - accuracy: 0.9023 - val_loss: 0.0763 - val_accuracy: 0.9742 - lr: 0.0010
# Epoch 2/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9793
# Epoch 2: val_accuracy improved from 0.97420 to 0.97980, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB4_224.h5
# 282/282 [==============================] - 196s 695ms/step - loss: 0.0681 - accuracy: 0.9793 - val_loss: 0.0543 - val_accuracy: 0.9798 - lr: 0.0010
# Epoch 3/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9899
# Epoch 3: val_accuracy improved from 0.97980 to 0.99100, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNetB4_224.h5
# 282/282 [==============================] - 173s 615ms/step - loss: 0.0362 - accuracy: 0.9899 - val_loss: 0.0235 - val_accuracy: 0.9910 - lr: 0.0010
# Epoch 4/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9897
# Epoch 4: val_accuracy improved from 0.99100 to 0.99720, saving model to /workspace/TelU-TugasAkhir/model/weights/model_EfficientNet
25
# 282/282 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9991
# Epoch 16: val_accuracy did not improve from 0.99960
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 282/282 [==============================] - 161s 570ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0029 - val_accuracy: 0.9992 - lr: 2.5000e-04
# Epoch 17/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9992
# Epoch 17: val_accuracy did not improve from 0.99960
# 282/282 [==============================] - 170s 604ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0017 - val_accuracy: 0.9994 - lr: 1.2500e-04
# Epoch 18/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9993
# Epoch 18: val_accuracy did not improve from 0.99960
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 282/282 [==============================] - 171s 606ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0012 - val_accuracy: 0.9994 - lr: 1.2500e-04
# Epoch 19/25
# 282/282 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 19: val_accuracy did not improve from 0.99960
# Restoring model weights from the end of the best epoch: 14.
# 282/282 [==============================] - 169s 598ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0014 - val_accuracy: 0.9994 - lr: 6.2500e-05
# Epoch 19: early stopping

# %%
# Record the end time
end_time = time.time()

# Calculate and print the training time
training_time = end_time - start_time
print(f"Training time: {training_time / 60:.2f} minutes")
# Out:
# Training time: 57.12 minutes

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_b3_224, test_generator, 'EfficientNetB3_224')
# Out:
# 32/32 [==============================] - 13s 422ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     0.9975    1.0000    0.9988       400
#      colon_n     1.0000    0.9975    0.9987       400
#     lung_aca     1.0000    1.0000    1.0000       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     1.0000    1.0000    1.0000       400
#
#     accuracy                         0.9995      2000
#    macro avg     0.9995    0.9995    0.9995      2000
# weighted avg     0.9995    0.9995    0.9995      2000

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(224, 224),  # Image size
    batch_size=64,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
# Record the start time
start_time = time.time()

# %%
callbacks_base_cnn_no_aug = create_callbacks(
    model_name='BaseCNN_no_aug',
    checkpoint_path=checkpoint_path,
    patience=5,       
)

base_cnn_no_aug = create_base_cnn(input_shape=(224, 224, 3))

history_base_cnn_no_aug, model_base_cnn_no_aug = train_and_plot(base_cnn_no_aug, 'Base_CNN_no_aug', train_generator_no_aug, val_generator, callbacks_base_cnn_no_aug,epochs=50)
# Out:
# Epoch 1/50
# 2024-11-06 18:11:52.779862: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_4/dropout_8/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 282/282 [==============================] - ETA: 0s - loss: 1.7485 - accuracy: 0.7698
# Epoch 1: val_accuracy improved from -inf to 0.64500, saving model to /workspace/TelU-TugasAkhir/model/weights/model_BaseCNN_no_aug.h5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 282/282 [==============================] - 161s 562ms/step - loss: 1.7485 - accuracy: 0.7698 - val_loss: 0.8884 - val_accuracy: 0.6450 - lr: 0.0010
# Epoch 2/50
# 282/282 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.8966
# Epoch 2: val_accuracy improved from 0.64500 to 0.73500, saving model to /workspace/TelU-TugasAkhir/model/weights/model_BaseCNN_no_aug.h5
# 282/282 [==============================] - 86s 306ms/step - loss: 0.2630 - accuracy: 0.8966 - val_loss: 0.6070 - val_accuracy: 0.7350 - lr: 0.0010
# Epoch 3/50
# 282/282 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9193
# Epoch 3: val_accuracy improved from 0.73500 to 0.91360, saving model to /workspace/TelU-TugasAkhir/model/weights/model_BaseCNN_no_aug.h5
# 282/282 [==============================] - 87s 307ms/step - loss: 0.2137 - accuracy: 0.9193 - val_loss: 0.2507 - val_accuracy: 0.9136 - lr: 0.0010
# Epoch 4/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1847 - accuracy: 0.9306
# Epoch 4: val_accuracy did not improve from 0.91360
# 282/282 [==============================] - 86s 306ms/step - loss: 0.1847 - accuracy: 0.9306 - val_loss: 0.3287 - val_accuracy: 0.8560 - lr: 0.0010
# Epoch 5/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9462
# Epoch 5: val_accuracy did not improve from 0.91360
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 282/282 [==============================] - 90s 318ms/step - loss: 0.1452 - accuracy: 0.9462 - val_loss: 0.4831 - val_accuracy: 0.7816 - lr: 0.0010
# Epoch 6/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9697
# Epoch 6: val_accuracy improved from 0.91360 to 0.94360, saving model to /workspace/TelU-TugasAkhir/model/weights/model_BaseCNN_no_aug.h5
# 282/282 [==============================] - 88s 312ms/step - loss: 0.0828 - accuracy: 0.9697 - val_loss: 0.1848 - val_accuracy: 0.9436 - lr: 5.0000e-04
# Epoch 7/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9763
# Epoch 7: val_accuracy improved from 0.94360 to 0.94400, saving model to /workspace/TelU-TugasAkhir/model/weights/model_BaseCNN_no_aug.h5
# 282/282 [==============================] - 89s 315ms/step - loss: 0.0616 - accuracy: 0.9763 - val_loss: 0.1816 - val_accuracy: 0.9440 - lr: 5.0000e-04
# Epoch 8/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9777
# Epoch 8: val_accuracy did not improve from 0.94400
# 282/282 [==============================] - 88s 311ms/step - loss: 0.0602 - accuracy: 0.9777 - val_loss: 0.3117 - val_accuracy: 0.9208 - lr: 5.0000e-04
# Epoch 9/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9801
# Epoch 9: val_accuracy improved from 0.94400 to 0.95900, saving model to /workspace/TelU-TugasAkhir/model/weights/model_BaseCNN_no_aug.h5
# 282/282 [==============================] - 89s 314ms/step - loss: 0.0543 - accuracy: 0.9801 - val_loss: 0.1294 - val_accuracy: 0.9590 - lr: 5.0000e-04
# Epoch 10/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9838
# Epoch 10: val_accuracy did not improve from 0.95900
# 282/282 [==============================] - 87s 309ms/step - loss: 0.0458 - accuracy: 0.9838 - val_loss: 0.2630 - val_accuracy: 0.9244 - lr: 5.0000e-04
# Epoch 11/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0439 - accuracy: 0.9850
# Epoch 11: val_accuracy did not improve from 0.95900
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 282/282 [==============================] - 86s 305ms/step - loss: 0.0439 - accuracy: 0.9850 - val_loss: 0.2486 - val_accuracy: 0.9228 - lr: 5.0000e-04
# Epoch 12/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9883
# Epoch 12: val_accuracy improved from 0.95900 to 0.97180, saving model to /workspace/TelU-TugasAkhir/model/weights/model_BaseCNN_no_aug.h5
# 282/282 [==============================] - 84s 299ms/step - loss: 0.0327 - accuracy: 0.9883 - val_loss: 0.1110 - val_accuracy: 0.9718 - lr: 2.5000e-04
# Epoch 13/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9905
# Epoch 13: val_accuracy did not improve from 0.97180
# 282/282 [==============================] - 86s 305ms/step - loss: 0.0254 - accuracy: 0.9905 - val_loss: 0.1546 - val_accuracy: 0.9590 - lr: 2.5000e-04
# Epoch 14/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9910
# Epoch 14: val_accuracy did not improve from 0.97180
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 282/282 [==============================] - 90s 321ms/step - loss: 0.0238 - accuracy: 0.9910 - val_loss: 0.2106 - val_accuracy: 0.9474 - lr: 2.5000e-04
# Epoch 15/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9931
# Epoch 15: val_accuracy did not improve from 0.97180
# 282/282 [==============================] - 87s 309ms/step - loss: 0.0180 - accuracy: 0.9931 - val_loss: 0.1208 - val_accuracy: 0.9708 - lr: 1.2500e-04
# Epoch 16/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9941
# Epoch 16: val_accuracy did not improve from 0.97180
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 282/282 [==============================] - 88s 314ms/step - loss: 0.0146 - accuracy: 0.9941 - val_loss: 0.1453 - val_accuracy: 0.9702 - lr: 1.2500e-04
# Epoch 17/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9952
# Epoch 17: val_accuracy improved from 0.97180 to 0.97260, saving model to /workspace/TelU-TugasAkhir/model/weights/model_BaseCNN_no_aug.h5
# Restoring model weights from the end of the best epoch: 12.
# 282/282 [==============================] - 86s 306ms/step - loss: 0.0118 - accuracy: 0.9952 - val_loss: 0.1301 - val_accuracy: 0.9726 - lr: 6.2500e-05
# Epoch 17: early stopping

# %%
# Record the end time
end_time = time.time()

# Calculate and print the training time
training_time = end_time - start_time
print(f"Training time: {training_time / 60:.2f} minutes")
# Out:
# Training time: 26.01 minutes

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(model_base_cnn_no_aug, test_generator, 'Base_CNN_no_aug')
# Out:
# 32/32 [==============================] - 13s 417ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     0.9974    0.9750    0.9861       400
#      colon_n     0.9756    0.9975    0.9864       400
#     lung_aca     0.9440    0.9700    0.9568       400
#       lung_n     0.9975    1.0000    0.9988       400
#     lung_scc     0.9716    0.9425    0.9569       400
#
#     accuracy                         0.9770      2000
#    macro avg     0.9772    0.9770    0.9770      2000
# weighted avg     0.9772    0.9770    0.9770      2000

# %%
train_generator_no_aug, train_generator_with_aug, val_generator, test_generator = create_image_generators(
    train_dir=train_dir,
    val_dir=val_dir,
    test_dir=test_dir,
    target_size=(224, 224),  # Image size
    batch_size=64,           # Batch size
    preprocessing_func=preprocess_input_func  # Optional preprocessing function (e.g., for VGG16 or other models)
)
# Out:
# Found 18000 images belonging to 5 classes.
# Found 18000 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.
# Found 2000 images belonging to 5 classes.

# %%
# Record the start time
start_time = time.time()

# %%
callbacks_base_cnn = create_callbacks(
    model_name='base_cnn',
    checkpoint_path=checkpoint_path,
    patience=8,       
)

base_cnn = create_base_cnn(input_shape=(224, 224, 3))

history_base_cnn, model_base_cnn = train_and_plot(base_cnn, 'Base_CNN', train_generator_with_aug, val_generator, callbacks_base_cnn,epochs=50)
# Out:
# Epoch 1/50
# 2024-11-06 21:18:04.441400: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_10/dropout_26/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 282/282 [==============================] - ETA: 0s - loss: 2.3985 - accuracy: 0.7138
# Epoch 1: val_accuracy improved from -inf to 0.62460, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 225s 795ms/step - loss: 2.3985 - accuracy: 0.7138 - val_loss: 1.3943 - val_accuracy: 0.6246 - lr: 0.0010
# Epoch 2/50
# 282/282 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.8214
# Epoch 2: val_accuracy improved from 0.62460 to 0.64460, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 180s 640ms/step - loss: 0.4515 - accuracy: 0.8214 - val_loss: 0.6297 - val_accuracy: 0.6446 - lr: 0.0010
# Epoch 3/50
# 282/282 [==============================] - ETA: 0s - loss: 0.3544 - accuracy: 0.8625
# Epoch 3: val_accuracy improved from 0.64460 to 0.70040, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 183s 650ms/step - loss: 0.3544 - accuracy: 0.8625 - val_loss: 1.3452 - val_accuracy: 0.7004 - lr: 0.0010
# Epoch 4/50
# 282/282 [==============================] - ETA: 0s - loss: 0.3068 - accuracy: 0.8852
# Epoch 4: val_accuracy improved from 0.70040 to 0.75960, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 180s 639ms/step - loss: 0.3068 - accuracy: 0.8852 - val_loss: 0.6174 - val_accuracy: 0.7596 - lr: 0.0010
# Epoch 5/50
# 282/282 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.9007
# Epoch 5: val_accuracy did not improve from 0.75960
# 282/282 [==============================] - 176s 626ms/step - loss: 0.2692 - accuracy: 0.9007 - val_loss: 1.7125 - val_accuracy: 0.5234 - lr: 0.0010
# Epoch 6/50
# 282/282 [==============================] - ETA: 0s - loss: 0.2427 - accuracy: 0.9116
# Epoch 6: val_accuracy improved from 0.75960 to 0.81700, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 282/282 [==============================] - 177s 629ms/step - loss: 0.2427 - accuracy: 0.9116 - val_loss: 0.7069 - val_accuracy: 0.8170 - lr: 0.0010
# Epoch 7/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1822 - accuracy: 0.9307
# Epoch 7: val_accuracy improved from 0.81700 to 0.93080, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 171s 606ms/step - loss: 0.1822 - accuracy: 0.9307 - val_loss: 0.1733 - val_accuracy: 0.9308 - lr: 5.0000e-04
# Epoch 8/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9376
# Epoch 8: val_accuracy did not improve from 0.93080
# 282/282 [==============================] - 174s 616ms/step - loss: 0.1708 - accuracy: 0.9376 - val_loss: 0.2011 - val_accuracy: 0.9268 - lr: 5.0000e-04
# Epoch 9/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9373
# Epoch 9: val_accuracy did not improve from 0.93080
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 282/282 [==============================] - 181s 643ms/step - loss: 0.1700 - accuracy: 0.9373 - val_loss: 0.2261 - val_accuracy: 0.9184 - lr: 5.0000e-04
# Epoch 10/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9459
# Epoch 10: val_accuracy improved from 0.93080 to 0.93440, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 175s 620ms/step - loss: 0.1453 - accuracy: 0.9459 - val_loss: 0.1739 - val_accuracy: 0.9344 - lr: 2.5000e-04
# Epoch 11/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 0.9483
# Epoch 11: val_accuracy did not improve from 0.93440
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 282/282 [==============================] - 177s 627ms/step - loss: 0.1348 - accuracy: 0.9483 - val_loss: 0.2382 - val_accuracy: 0.9186 - lr: 2.5000e-04
# Epoch 12/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9539
# Epoch 12: val_accuracy improved from 0.93440 to 0.94980, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 178s 633ms/step - loss: 0.1226 - accuracy: 0.9539 - val_loss: 0.1396 - val_accuracy: 0.9498 - lr: 1.2500e-04
# Epoch 13/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.9560
# Epoch 13: val_accuracy did not improve from 0.94980
# 282/282 [==============================] - 199s 706ms/step - loss: 0.1211 - accuracy: 0.9560 - val_loss: 0.1860 - val_accuracy: 0.9388 - lr: 1.2500e-04
# Epoch 14/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9572
# Epoch 14: val_accuracy improved from 0.94980 to 0.95120, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 205s 728ms/step - loss: 0.1140 - accuracy: 0.9572 - val_loss: 0.1233 - val_accuracy: 0.9512 - lr: 1.2500e-04
# Epoch 15/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9573
# Epoch 15: val_accuracy improved from 0.95120 to 0.95700, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 197s 699ms/step - loss: 0.1115 - accuracy: 0.9573 - val_loss: 0.1098 - val_accuracy: 0.9570 - lr: 1.2500e-04
# Epoch 16/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9611
# Epoch 16: val_accuracy did not improve from 0.95700
# 282/282 [==============================] - 182s 647ms/step - loss: 0.1076 - accuracy: 0.9611 - val_loss: 0.1267 - val_accuracy: 0.9542 - lr: 1.2500e-04
# Epoch 17/50
# 282/282 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9609
# Epoch 17: val_accuracy did not improve from 0.95700
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 282/282 [==============================] - 175s 622ms/step - loss: 0.1032 - accuracy: 0.9609 - val_loss: 0.1792 - val_accuracy: 0.9384 - lr: 1.2500e-04
# Epoch 18/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9631
# Epoch 18: val_accuracy did not improve from 0.95700
# 282/282 [==============================] - 171s 608ms/step - loss: 0.0970 - accuracy: 0.9631 - val_loss: 0.1424 - val_accuracy: 0.9478 - lr: 6.2500e-05
# Epoch 19/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9628
# Epoch 19: val_accuracy improved from 0.95700 to 0.95940, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 177s 628ms/step - loss: 0.0953 - accuracy: 0.9628 - val_loss: 0.1051 - val_accuracy: 0.9594 - lr: 6.2500e-05
# Epoch 20/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9644
# Epoch 20: val_accuracy did not improve from 0.95940
# 282/282 [==============================] - 170s 605ms/step - loss: 0.0921 - accuracy: 0.9644 - val_loss: 0.1546 - val_accuracy: 0.9472 - lr: 6.2500e-05
# Epoch 21/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9679
# Epoch 21: val_accuracy did not improve from 0.95940
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 282/282 [==============================] - 203s 722ms/step - loss: 0.0885 - accuracy: 0.9679 - val_loss: 0.1112 - val_accuracy: 0.9580 - lr: 6.2500e-05
# Epoch 22/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9658
# Epoch 22: val_accuracy improved from 0.95940 to 0.96160, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 189s 671ms/step - loss: 0.0856 - accuracy: 0.9658 - val_loss: 0.0967 - val_accuracy: 0.9616 - lr: 3.1250e-05
# Epoch 23/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9697
# Epoch 23: val_accuracy did not improve from 0.96160
# 282/282 [==============================] - 182s 647ms/step - loss: 0.0802 - accuracy: 0.9697 - val_loss: 0.1337 - val_accuracy: 0.9512 - lr: 3.1250e-05
# Epoch 24/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9679
# Epoch 24: val_accuracy did not improve from 0.96160
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 282/282 [==============================] - 169s 600ms/step - loss: 0.0877 - accuracy: 0.9679 - val_loss: 0.1052 - val_accuracy: 0.9584 - lr: 3.1250e-05
# Epoch 25/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9693
# Epoch 25: val_accuracy did not improve from 0.96160
# 282/282 [==============================] - 166s 590ms/step - loss: 0.0794 - accuracy: 0.9693 - val_loss: 0.1024 - val_accuracy: 0.9610 - lr: 1.5625e-05
# Epoch 26/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9716
# Epoch 26: val_accuracy improved from 0.96160 to 0.96560, saving model to /workspace/TelU-TugasAkhir/model/weights/model_base_cnn.h5
# 282/282 [==============================] - 173s 614ms/step - loss: 0.0749 - accuracy: 0.9716 - val_loss: 0.0920 - val_accuracy: 0.9656 - lr: 1.5625e-05
# Epoch 27/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9712
# Epoch 27: val_accuracy did not improve from 0.96560
# 282/282 [==============================] - 167s 592ms/step - loss: 0.0745 - accuracy: 0.9712 - val_loss: 0.1260 - val_accuracy: 0.9548 - lr: 1.5625e-05
# Epoch 28/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9716
# Epoch 28: val_accuracy did not improve from 0.96560
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 282/282 [==============================] - 161s 569ms/step - loss: 0.0766 - accuracy: 0.9716 - val_loss: 0.1131 - val_accuracy: 0.9582 - lr: 1.5625e-05
# Epoch 29/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9709
# Epoch 29: val_accuracy did not improve from 0.96560
# 282/282 [==============================] - 167s 591ms/step - loss: 0.0773 - accuracy: 0.9709 - val_loss: 0.1055 - val_accuracy: 0.9616 - lr: 7.8125e-06
# Epoch 30/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9712
# Epoch 30: val_accuracy did not improve from 0.96560
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 282/282 [==============================] - 192s 680ms/step - loss: 0.0736 - accuracy: 0.9712 - val_loss: 0.1064 - val_accuracy: 0.9606 - lr: 7.8125e-06
# Epoch 31/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0762 - accuracy: 0.9713
# Epoch 31: val_accuracy did not improve from 0.96560
# 282/282 [==============================] - 199s 706ms/step - loss: 0.0762 - accuracy: 0.9713 - val_loss: 0.1029 - val_accuracy: 0.9618 - lr: 3.9063e-06
# Epoch 32/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9711
# Epoch 32: val_accuracy did not improve from 0.96560
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 282/282 [==============================] - 178s 633ms/step - loss: 0.0747 - accuracy: 0.9711 - val_loss: 0.1093 - val_accuracy: 0.9604 - lr: 3.9063e-06
# Epoch 33/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9720
# Epoch 33: val_accuracy did not improve from 0.96560
# 282/282 [==============================] - 170s 604ms/step - loss: 0.0736 - accuracy: 0.9720 - val_loss: 0.1049 - val_accuracy: 0.9604 - lr: 1.9531e-06
# Epoch 34/50
# 282/282 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9704
# Epoch 34: val_accuracy did not improve from 0.96560
# Restoring model weights from the end of the best epoch: 26.
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
# 282/282 [==============================] - 164s 583ms/step - loss: 0.0743 - accuracy: 0.9704 - val_loss: 0.1035 - val_accuracy: 0.9614 - lr: 1.9531e-06
# Epoch 34: early stopping

# %%
# Record the end time
end_time = time.time()

# Calculate and print the training time
training_time = end_time - start_time
print(f"Training time: {training_time / 60:.2f} minutes")
# Out:
# Training time: 125.51 minutes

# %%
# Call the function after you have trained your model
report_file, cm_file = show_cm_and_classification_report(base_cnn, test_generator, 'Base_CNN')
# Out:
# 32/32 [==============================] - 13s 404ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#    colon_aca     0.9704    0.9825    0.9764       400
#      colon_n     0.9803    0.9950    0.9876       400
#     lung_aca     0.9629    0.9075    0.9344       400
#       lung_n     1.0000    1.0000    1.0000       400
#     lung_scc     0.9175    0.9450    0.9310       400
#
#     accuracy                         0.9660      2000
#    macro avg     0.9662    0.9660    0.9659      2000
# weighted avg     0.9662    0.9660    0.9659      2000
